# %%
from InitialGraphs import Graphdata
from InitialPattern2 import Pattern
from GraphPattern import PatternMarge
import NPGSAlgorithm as na
import time
import os
import math

fileName = 'ENZYMES'
pers = 10 # N-hop Pattern Filtering Ratio
psize = 100 # 𝐹𝑟𝑒𝑞𝑢𝑒𝑛𝑡 𝑃𝑎𝑡𝑡𝑒𝑟𝑛 𝑀𝑎𝑛𝑎𝑔𝑚𝑒𝑛𝑡 Table Size
batchsize = 3
windowsize = 10
DxMtrix = {}
ExceptionList = {}
iterations = 0
iterations2 = 0
FPMT = {}
th2 = batchsize * windowsize

def Top_nPercent(dict, n):
    if len(dict) == 0:
        return 0
    part_v = len(dict)*n//100
    value = list(sorted(dict.items(), key = lambda item: item[1], reverse = True))[part_v][1]
    return value

def convert_size(size_bytes):
    if size_bytes == 0:
        return "0B"
    size_name = ("B", "KB", "MB", "GB", "TB", "PB", "EB", "ZB", "YB")
    i = int(math.floor(math.log(size_bytes, 1024)))
    p = math.pow(1024, i)
    s = round(size_bytes / p, 2)
    return "%s %s" % (s, size_name[i])


for i in range(100):
    s1 = time.time()
    # IGPath = './Gen_Evolution_set/' + fileName + '/' + fileName + '_' + str(i) + '.edges'
    # lbPath = './dataset/' + fileName + '/' + fileName + '.node_labels'
    IGPath = './Gen_Evolution_set/' + fileName + '/' + fileName + '_' + str(i) + '.edges'
    lbPath = './dataset/' + fileName + '/' + fileName + '.node_labels'
    Separator = ','

    DataT0 = Graphdata(IGPath, lbPath, Separator)
    Th1 = Top_nPercent(DataT0.OhP, pers)
    
    iterations = i%batchsize
    
    if iterations < batchsize:
        FP = DataT0.OhP

        for ohp in FP.keys():
            ohpRe = ohp.split('/')
            ohpRe.reverse()
            ohpReverse = '/'.join(ohpRe)
            
            if ohp not in DxMtrix or ohpReverse not in DxMtrix:
                Raw = [[0 for col in range(batchsize)] for row in range(windowsize)]
                if FP[ohp] >= Th1:
                    Raw[iterations2][iterations] = 1
                    DxMtrix[ohp] = Raw
            else:
                if FP[ohp] >= Th1:
                    if ohpReverse in DxMtrix:
                        DxMtrix[ohpReverse][iterations2][iterations] = 1
                    else:
                        DxMtrix[ohp][iterations2][iterations] = 1
        
        if iterations == batchsize-1:
            for ohp in DxMtrix:
                if ohp not in FPMT:
                    Raw2 = [0 for col in range(windowsize+2)]
                    Raw2[iterations2] = sum(DxMtrix[ohp][iterations2])
                    FPMT[ohp] = Raw2
                else:
                    if i >= th2:
                        if FPMT[ohp][windowsize+1] == 0:
                            FPMT[ohp][iterations2] = sum(DxMtrix[ohp][iterations2])
                    else:
                        FPMT[ohp][iterations2] = sum(DxMtrix[ohp][iterations2])
                        
            for nhp in FPMT:
                if i >= th2:
                    if FPMT[nhp][windowsize+1] != 0:
                        FPMT[nhp][iterations2] = 0
                        FPMT[nhp][windowsize+1] = 0
                        FPMT[nhp][windowsize] = sum(FPMT[nhp][:windowsize])
                        ExceptionList[nhp] = FPMT[nhp]
                    else:
                        FPMT[nhp][windowsize] = sum(FPMT[nhp][:windowsize])
                        if FPMT[nhp][windowsize] <= int(th2*0.4):
                            FPMT[nhp][windowsize+1] = -1
                        elif FPMT[nhp][windowsize] >= int(th2*0.8):
                            FPMT[nhp][windowsize+1] = 1
                        else:
                            FPMT[nhp][windowsize+1] = 0
                else:
                    FPMT[nhp][windowsize] = sum(FPMT[nhp][:windowsize])
                    if FPMT[nhp][windowsize] <= int(th2*0.4):
                        FPMT[nhp][windowsize+1] = -1
                    elif FPMT[nhp][windowsize] >= int(th2*0.8):
                        FPMT[nhp][windowsize+1] = 1
                    else:
                        FPMT[nhp][windowsize+1] = 0

            iterations2 += 1
            
            if iterations2 == windowsize:
                iterations2 = 0
       
    updateWindow = (i+1)%th2
    if updateWindow == 0:
        for nhp in FPMT:
            if FPMT[nhp][windowsize] == 0:
                del FPMT[nhp]
                
    if i >= th2-1:
        DataP0 = Pattern(FPMT, DxMtrix, ExceptionList, th2, psize)
        FPMT = DataP0.NhP
        ExceptionList = {}
        PM = PatternMarge(DataT0.IG, FPMT, DataT0.lbDict, DataT0.nList)
        Ge = PM.SG
        P_id_list = list(sorted(PM.pidDict.items(), key = lambda item: item[1], reverse = True))
        Gp = P_id_list
        Gl = list(sorted(PM.SGnl.items()))
        e1 = time.time() - s1
        
        savefile = './Result/FPGS2/'+ fileName + '/' + fileName + '_' + str(len(FPMT)) + '_' + str(pers) + '_' + str(i)
        savedata = [Ge, Gl, Gp]
        extension = ['.edges', '.node_labels', '.pattern']
        
        for sd in range(len(savedata)):
            f = open(savefile + extension[sd], 'w')
            for e in savedata[sd]:
                str_e = e[0] + ',' + e[1] + '\n'
                f.write(str_e)
        f.close()

        FPMTs = len(FPMT)
        NLs = len(PM.SGnl)
        Es = len(PM.SG)
        
        file_size = 0
        for e in extension:
            file_size = file_size + os.path.getsize(savefile + e) 
            print(e.split('.')[1], convert_size(os.path.getsize(savefile + e)))
        print('OutPut File Size:', convert_size(file_size), 'bytes')

        input_file = [IGPath, lbPath]
        file_size1 = 0
        for ip in input_file:
            file_size1 = file_size1 + os.path.getsize(ip)
            print(ip.split('.')[2], convert_size(os.path.getsize(savefile + e)))
        print('InPut File Size:', convert_size(file_size), 'bytes')
        
        print(f'Th : {Th1}, FPMTs: {FPMTs}, NLs: {NLs}, Es: {Es}, Time: {e1}')
        
        IGPath2 = savefile + '.edges' #sys.argv[1]
        lbPath2 = savefile + '.node_labels' #sys.argv[2]
        Separator = ','
        t = 2

        G = Graphdata(IGPath2, lbPath2, Separator).IG
        E = G.edge_list
        Gc = na.Basic(Ge, t, E)
        print(len(Gc.edge_list))
# Out:
# edges 267.35 KB
# node_labels 107.45 KB
# pattern 199.0 B
# OutPut File Size: 374.99 KB bytes
# edges 199.0 B
# node_labels 199.0 B
# InPut File Size: 374.99 KB bytes
# Th : 24224, FPMTs: 11, NLs: 12639, Es: 22564, Time: 26.812174081802368
# 17796
# edges 264.24 KB
# node_labels 107.16 KB
# pattern 599.0 B
# OutPut File Size: 371.98 KB bytes
# edges 599.0 B
# node_labels 599.0 B
# InPut File Size: 371.98 KB bytes
# Th : 22041, FPMTs: 21, NLs: 12611, Es: 22311, Time: 26.001331567764282
# 17614
# edges 264.5 KB
# node_labels 107.06 KB
# pattern 660.0 B
# OutPut File Size: 372.21 KB bytes
# edges 660.0 B
# node_labels 660.0 B
# InPut File Size: 372.21 KB bytes
# Th : 22252, FPMTs: 31, NLs: 12598, Es: 22332, Time: 26.8120858669281
# 17653
# edges 264.76 KB
# node_labels 107.01 KB
# pattern 650.0 B
# OutPut File Size: 372.4 KB bytes
# edges 650.0 B
# node_labels 650.0 B
# InPut File Size: 372.4 KB bytes
# Th : 22479, FPMTs: 41, NLs: 12594, Es: 22357, Time: 25.934640645980835
# 17649
# edges 265.17 KB
# node_labels 106.96 KB
# pattern 705.0 B
# OutPut File Size: 372.82 KB bytes
# edges 705.0 B
# node_labels 705.0 B
# InPut File Size: 372.82 KB bytes
# Th : 22787, FPMTs: 51, NLs: 12584, Es: 22387, Time: 26.851993322372437
# 17642
# edges 265.25 KB
# node_labels 106.94 KB
# pattern 603.0 B
# OutPut File Size: 372.78 KB bytes
# edges 603.0 B
# node_labels 603.0 B
# InPut File Size: 372.78 KB bytes
# Th : 23014, FPMTs: 55, NLs: 12583, Es: 22399, Time: 26.778326272964478
# 17667
# edges 265.54 KB
# node_labels 106.84 KB
# pattern 658.0 B
# OutPut File Size: 373.02 KB bytes
# edges 658.0 B
# node_labels 658.0 B
# InPut File Size: 373.02 KB bytes
# Th : 23254, FPMTs: 65, NLs: 12575, Es: 22422, Time: 26.8088161945343
# 17666
# edges 265.48 KB
# node_labels 106.86 KB
# pattern 650.0 B
# OutPut File Size: 372.98 KB bytes
# edges 650.0 B
# node_labels 650.0 B
# InPut File Size: 372.98 KB bytes
# Th : 23503, FPMTs: 65, NLs: 12575, Es: 22421, Time: 26.43934941291809
# 17676
# edges 265.97 KB
# node_labels 106.89 KB
# pattern 603.0 B
# OutPut File Size: 373.45 KB bytes
# edges 603.0 B
# node_labels 603.0 B
# InPut File Size: 373.45 KB bytes
# Th : 23763, FPMTs: 65, NLs: 12577, Es: 22455, Time: 26.343322277069092
# 17700
# edges 266.09 KB
# node_labels 106.91 KB
# pattern 601.0 B
# OutPut File Size: 373.59 KB bytes
# edges 601.0 B
# node_labels 601.0 B
# InPut File Size: 373.59 KB bytes
# Th : 23967, FPMTs: 65, NLs: 12579, Es: 22468, Time: 26.2318332195282
# 17710
# edges 265.96 KB
# node_labels 106.85 KB
# pattern 601.0 B
# OutPut File Size: 373.4 KB bytes
# edges 601.0 B
# node_labels 601.0 B
# InPut File Size: 373.4 KB bytes
# Th : 24238, FPMTs: 65, NLs: 12572, Es: 22456, Time: 25.844252109527588
# 17691
# edges 264.01 KB
# node_labels 107.05 KB
# pattern 605.0 B
# OutPut File Size: 371.65 KB bytes
# edges 605.0 B
# node_labels 605.0 B
# InPut File Size: 371.65 KB bytes
# Th : 21982, FPMTs: 65, NLs: 12598, Es: 22294, Time: 24.33747911453247
# 17630
# edges 264.29 KB
# node_labels 106.91 KB
# pattern 656.0 B
# OutPut File Size: 371.83 KB bytes
# edges 656.0 B
# node_labels 656.0 B
# InPut File Size: 371.83 KB bytes
# Th : 22254, FPMTs: 65, NLs: 12577, Es: 22309, Time: 25.21409010887146
# 17616
# edges 264.5 KB
# node_labels 106.96 KB
# pattern 605.0 B
# OutPut File Size: 372.05 KB bytes
# edges 605.0 B
# node_labels 605.0 B
# InPut File Size: 372.05 KB bytes
# Th : 22563, FPMTs: 65, NLs: 12585, Es: 22329, Time: 24.561192750930786
# 17648
# edges 265.34 KB
# node_labels 107.01 KB
# pattern 603.0 B
# OutPut File Size: 372.94 KB bytes
# edges 603.0 B
# node_labels 603.0 B
# InPut File Size: 372.94 KB bytes
# Th : 22790, FPMTs: 65, NLs: 12593, Es: 22403, Time: 25.464704513549805
# 17671
# edges 264.99 KB
# node_labels 106.87 KB
# pattern 656.0 B
# OutPut File Size: 372.49 KB bytes
# edges 656.0 B
# node_labels 656.0 B
# InPut File Size: 372.49 KB bytes
# Th : 23082, FPMTs: 65, NLs: 12575, Es: 22376, Time: 26.143200397491455
# 17643
# edges 265.38 KB
# node_labels 106.94 KB
# pattern 603.0 B
# OutPut File Size: 372.91 KB bytes
# edges 603.0 B
# node_labels 603.0 B
# InPut File Size: 372.91 KB bytes
# Th : 23241, FPMTs: 65, NLs: 12583, Es: 22413, Time: 24.927672624588013
# 17676
# edges 265.55 KB
# node_labels 106.88 KB
# pattern 560.0 B
# OutPut File Size: 372.98 KB bytes
# edges 560.0 B
# node_labels 560.0 B
# InPut File Size: 372.98 KB bytes
# Th : 23548, FPMTs: 65, NLs: 12576, Es: 22421, Time: 25.527170419692993
# 17684
# edges 265.76 KB
# node_labels 106.78 KB
# pattern 658.0 B
# OutPut File Size: 373.18 KB bytes
# edges 658.0 B
# node_labels 658.0 B
# InPut File Size: 373.18 KB bytes
# Th : 23748, FPMTs: 65, NLs: 12564, Es: 22438, Time: 27.81155562400818
# 17696
# edges 266.08 KB
# node_labels 106.81 KB
# pattern 703.0 B
# OutPut File Size: 373.58 KB bytes
# edges 703.0 B
# node_labels 703.0 B
# InPut File Size: 373.58 KB bytes
# Th : 23975, FPMTs: 65, NLs: 12570, Es: 22461, Time: 27.794005632400513
# 17708
# edges 266.0 KB
# node_labels 106.88 KB
# pattern 656.0 B
# OutPut File Size: 373.52 KB bytes
# edges 656.0 B
# node_labels 656.0 B
# InPut File Size: 373.52 KB bytes
# Th : 24241, FPMTs: 65, NLs: 12574, Es: 22455, Time: 28.543199062347412
# 17700
# edges 264.12 KB
# node_labels 107.1 KB
# pattern 654.0 B
# OutPut File Size: 371.86 KB bytes
# edges 654.0 B
# node_labels 654.0 B
# InPut File Size: 371.86 KB bytes
# Th : 22041, FPMTs: 65, NLs: 12604, Es: 22298, Time: 27.06590962409973
# 17629
# edges 264.76 KB
# node_labels 107.17 KB
# pattern 509.0 B
# OutPut File Size: 372.44 KB bytes
# edges 509.0 B
# node_labels 509.0 B
# InPut File Size: 372.44 KB bytes
# Th : 22212, FPMTs: 65, NLs: 12611, Es: 22355, Time: 26.635287046432495
# 17667
# edges 265.18 KB
# node_labels 107.09 KB
# pattern 605.0 B
# OutPut File Size: 372.85 KB bytes
# edges 605.0 B
# node_labels 605.0 B
# InPut File Size: 372.85 KB bytes
# Th : 22513, FPMTs: 65, NLs: 12603, Es: 22391, Time: 26.75676155090332
# 17674
# edges 265.13 KB
# node_labels 106.93 KB
# pattern 666.0 B
# OutPut File Size: 372.71 KB bytes
# edges 666.0 B
# node_labels 666.0 B
# InPut File Size: 372.71 KB bytes
# Th : 22774, FPMTs: 65, NLs: 12581, Es: 22385, Time: 26.63774609565735
# 17675
# edges 265.21 KB
# node_labels 106.88 KB
# pattern 603.0 B
# OutPut File Size: 372.68 KB bytes
# edges 603.0 B
# node_labels 603.0 B
# InPut File Size: 372.68 KB bytes
# Th : 23028, FPMTs: 65, NLs: 12575, Es: 22390, Time: 27.073777198791504
# 17670
# edges 265.43 KB
# node_labels 106.92 KB
# pattern 554.0 B
# OutPut File Size: 372.89 KB bytes
# edges 554.0 B
# node_labels 554.0 B
# InPut File Size: 372.89 KB bytes
# Th : 23240, FPMTs: 65, NLs: 12577, Es: 22404, Time: 25.880533695220947
# 17674
# edges 265.72 KB
# node_labels 106.83 KB
# pattern 607.0 B
# OutPut File Size: 373.15 KB bytes
# edges 607.0 B
# node_labels 607.0 B
# InPut File Size: 373.15 KB bytes
# Th : 23526, FPMTs: 65, NLs: 12569, Es: 22440, Time: 27.039489269256592
# 17692
# edges 265.76 KB
# node_labels 106.87 KB
# pattern 654.0 B
# OutPut File Size: 373.28 KB bytes
# edges 654.0 B
# node_labels 654.0 B
# InPut File Size: 373.28 KB bytes
# Th : 23729, FPMTs: 65, NLs: 12577, Es: 22442, Time: 26.218682765960693
# 17689
# edges 265.76 KB
# node_labels 106.74 KB
# pattern 650.0 B
# OutPut File Size: 373.13 KB bytes
# edges 650.0 B
# node_labels 650.0 B
# InPut File Size: 373.13 KB bytes
# Th : 24020, FPMTs: 65, NLs: 12560, Es: 22444, Time: 25.1315758228302
# 17675
# edges 265.79 KB
# node_labels 106.81 KB
# pattern 660.0 B
# OutPut File Size: 373.25 KB bytes
# edges 660.0 B
# node_labels 660.0 B
# InPut File Size: 373.25 KB bytes
# Th : 24229, FPMTs: 65, NLs: 12566, Es: 22445, Time: 25.428510427474976
# 17686
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30652\1745266526.py in <module>
#     121         FPMT = DataP0.NhP
#     122         ExceptionList = {}
# --> 123         PM = PatternMarge(DataT0.IG, FPMT, DataT0.lbDict, DataT0.nList)
#     124         Ge = PM.SG
#     125         P_id_list = list(sorted(PM.pidDict.items(), key = lambda item: item[1], reverse = True))
#
# c:\Users\Hyeuk\Desktop\NetDB\projects\NPGS\GraphPattern.py in __init__(self, IG, NhP, lbDict, nList)
#     129                     continue
#     130                 if [SGn, SGnn] not in self.SG and [SGnn, SGn] not in self.SG:
# --> 131                     self.SG.append([SGn, SGnn])
#     132                 if SGnn not in self.SGnl:
#     133                     if SGnn in lbDict:
#
# KeyboardInterrupt:
